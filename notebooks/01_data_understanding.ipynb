# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

print("Environment ready!")
# Out:
# Matplotlib is building the font cache; this may take a moment.
# Environment ready!

# %%
import sys

print(sys.executable)
# Out:
# /opt/anaconda3/envs/credit-risk/bin/python

# %%
import pandas as pd

file_path = "data/raw/default of credit card clients.xls"

df = pd.read_excel(file_path,header=1)

df.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...          0          0          0         0       689         0
# 1  ...       3272       3455       3261         0      1000      1000
# 2  ...      14331      14948      15549      1518      1500      1000
# 3  ...      28314      28959      29547      2000      2019      1200
# 4  ...      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# ...

# %%
df.shape
# Out:
# (30000, 25)

# %%
df.columns.tolist()
# Out:
# ['ID',
#  'LIMIT_BAL',
#  'SEX',
#  'EDUCATION',
#  'MARRIAGE',
#  'AGE',
#  'PAY_0',
#  'PAY_2',
#  'PAY_3',
#  'PAY_4',
#  'PAY_5',
#  'PAY_6',
#  'BILL_AMT1',
#  'BILL_AMT2',
#  'BILL_AMT3',
#  'BILL_AMT4',
#  'BILL_AMT5',
#  'BILL_AMT6',
#  'PAY_AMT1',
#  'PAY_AMT2',
#  'PAY_AMT3',
#  'PAY_AMT4',
#  'PAY_AMT5',
#  'PAY_AMT6',
#  'default payment next month']

# %%
df["default payment next month"].value_counts()
# Out:
# default payment next month
# 0    23364
# 1     6636
# Name: count, dtype: int64

# %%
df["default payment next month"].value_counts(normalize=True)
# Out:
# default payment next month
# 0    0.7788
# 1    0.2212
# Name: proportion, dtype: float64

# %%
for column in ["SEX", "EDUCATION", "MARRIAGE"]:
    print(f"\n{column}")
    print(df[column].value_counts().sort_index())
# Out:
# SEX
# SEX
# 1    11888
# 2    18112
# Name: count, dtype: int64
#
# EDUCATION
# EDUCATION
# 0       14
# 1    10585
# 2    14030
# 3     4917
# 4      123
# 5      280
# 6       51
# Name: count, dtype: int64
#
# MARRIAGE
# MARRIAGE
# 0       54
# 1    13659
# 2    15964
# 3      323
# Name: count, dtype: int64

# %%
df[column].value_counts()
# Out:
# MARRIAGE
# 2    15964
# 1    13659
# 3      323
# 0       54
# Name: count, dtype: int64

# %%
df = df[df["EDUCATION"] != 0]

# %% [markdown]
# ### Initial Categorical Variable Findings
#
# - `SEX` contains two categories (1 and 2) with no unexpected values observed.
# - `EDUCATION` contains values from 0 to 6. Some categories are sparsely represented, and category 0 requires further investigation because it is not clearly documented.
# - `MARRIAGE` contains values from 0 to 3. Category 0 is uncommon and requires further investigation.
# - These values will be reviewed against the dataset documentation before deciding how they should be handled during preprocessing.

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# ID                            0
# BILL_AMT2                     0
# PAY_AMT6                      0
# PAY_AMT5                      0
# PAY_AMT4                      0
# PAY_AMT3                      0
# PAY_AMT2                      0
# PAY_AMT1                      0
# BILL_AMT6                     0
# BILL_AMT5                     0
# BILL_AMT4                     0
# BILL_AMT3                     0
# BILL_AMT1                     0
# LIMIT_BAL                     0
# PAY_6                         0
# PAY_5                         0
# PAY_4                         0
# PAY_3                         0
# PAY_2                         0
# PAY_0                         0
# AGE                           0
# MARRIAGE                      0
# EDUCATION                     0
# SEX                           0
# default payment next month    0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["ID"].nunique()
# Out:
# 30000

# %%
len(df)
# Out:
# 30000

# %%
df.shape
# Out:
# (29986, 25)

# %%
df["EDUCATION"].value_counts().sort_index()
# Out:
# EDUCATION
# 1    10585
# 2    14030
# 3     4917
# 4      123
# 5      280
# 6       51
# Name: count, dtype: int64

# %%
file_path = "data/raw/default of credit card clients.xls"

df = pd.read_excel(file_path, header=1)

# %%
print("Shape:", df.shape)
print("Unique IDs:", df["ID"].nunique())
print("Duplicate rows:", df.duplicated().sum())
# Out:
# Shape: (30000, 25)
# Unique IDs: 30000
# Duplicate rows: 0

# %%
df["EDUCATION"].value_counts().sort_index()
# Out:
# EDUCATION
# 0       14
# 1    10585
# 2    14030
# 3     4917
# 4      123
# 5      280
# 6       51
# Name: count, dtype: int64

# %%
df["ID"].nunique()
# Out:
# 30000

# %%
pay_columns = ["PAY_0", "PAY_2", "PAY_3", "PAY_4", "PAY_5", "PAY_6"]

for column in pay_columns:
    print(f"\n{column}")
    print(df[column].value_counts().sort_index())
# Out:
# PAY_0
# PAY_0
# -2     2759
# -1     5686
#  0    14737
#  1     3688
#  2     2667
#  3      322
#  4       76
#  5       26
#  6       11
#  7        9
#  8       19
# Name: count, dtype: int64
#
# PAY_2
# PAY_2
# -2     3782
# -1     6050
#  0    15730
#  1       28
#  2     3927
#  3      326
#  4       99
#  5       25
#  6       12
#  7       20
#  8        1
# Name: count, dtype: int64
#
# PAY_3
# PAY_3
# -2     4085
# -1     5938
#  0    15764
#  1        4
#  2     3819
#  3      240
#  4       76
#  5       21
#  6       23
#  7       27
#  8        3
# Name: count, dtype: int64
#
# PAY_4
# PAY_4
# -2     4348
# -1     5687
#  0    16455
#  1        2
#  2     3159
#  3      180
#  4       69
#  5       35
#  6        5
#  7       58
#  8        2
# Name: count, dtype: int64
#
# PAY_5
# PAY_5
# -2     4546
# -1     5539
#  0    16947
#  2     2626
#  3      178
#  4       84
#  5       17
#  6        4
#  7       58
#  8        1
# Name: count, dtype: int64
#
# PAY_6
# ...

# %%
df[pay_columns].describe()
# Out:
#               PAY_0         PAY_2         PAY_3         PAY_4         PAY_5  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      -0.016700     -0.133767     -0.166200     -0.220667     -0.266200
# std        1.123802      1.197186      1.196868      1.169139      1.133187
# min       -2.000000     -2.000000     -2.000000     -2.000000     -2.000000
# 25%       -1.000000     -1.000000     -1.000000     -1.000000     -1.000000
# 50%        0.000000      0.000000      0.000000      0.000000      0.000000
# 75%        0.000000      0.000000      0.000000      0.000000      0.000000
# max        8.000000      8.000000      8.000000      8.000000      8.000000
#
#               PAY_6
# count  30000.000000
# mean      -0.291100
# std        1.149988
# min       -2.000000
# 25%       -1.000000
# 50%        0.000000
# 75%        0.000000
# max        8.000000

# %%
for column in pay_columns:
    print(
        column,
        "min:", df[column].min(),
        "max:", df[column].max()
    )
# Out:
# PAY_0 min: -2 max: 8
# PAY_2 min: -2 max: 8
# PAY_3 min: -2 max: 8
# PAY_4 min: -2 max: 8
# PAY_5 min: -2 max: 8
# PAY_6 min: -2 max: 8

# %%
pay_columns = ["PAY_0", "PAY_2", "PAY_3", "PAY_4", "PAY_5", "PAY_6"]

for column in pay_columns:
    print(f"\n{column}")
    print(df[column].value_counts().sort_index())
# Out:
# PAY_0
# PAY_0
# -2     2759
# -1     5686
#  0    14737
#  1     3688
#  2     2667
#  3      322
#  4       76
#  5       26
#  6       11
#  7        9
#  8       19
# Name: count, dtype: int64
#
# PAY_2
# PAY_2
# -2     3782
# -1     6050
#  0    15730
#  1       28
#  2     3927
#  3      326
#  4       99
#  5       25
#  6       12
#  7       20
#  8        1
# Name: count, dtype: int64
#
# PAY_3
# PAY_3
# -2     4085
# -1     5938
#  0    15764
#  1        4
#  2     3819
#  3      240
#  4       76
#  5       21
#  6       23
#  7       27
#  8        3
# Name: count, dtype: int64
#
# PAY_4
# PAY_4
# -2     4348
# -1     5687
#  0    16455
#  1        2
#  2     3159
#  3      180
#  4       69
#  5       35
#  6        5
#  7       58
#  8        2
# Name: count, dtype: int64
#
# PAY_5
# PAY_5
# -2     4546
# -1     5539
#  0    16947
#  2     2626
#  3      178
#  4       84
#  5       17
#  6        4
#  7       58
#  8        1
# Name: count, dtype: int64
#
# PAY_6
# ...

# %% [markdown]
# ## 7. Repayment Variables

# %%
pay_columns = ["PAY_0", "PAY_2", "PAY_3", "PAY_4", "PAY_5", "PAY_6"]

for column in pay_columns:
    print(f"\n{column}")
    print(df[column].value_counts().sort_index())
# Out:
# PAY_0
# PAY_0
# -2     2759
# -1     5686
#  0    14737
#  1     3688
#  2     2667
#  3      322
#  4       76
#  5       26
#  6       11
#  7        9
#  8       19
# Name: count, dtype: int64
#
# PAY_2
# PAY_2
# -2     3782
# -1     6050
#  0    15730
#  1       28
#  2     3927
#  3      326
#  4       99
#  5       25
#  6       12
#  7       20
#  8        1
# Name: count, dtype: int64
#
# PAY_3
# PAY_3
# -2     4085
# -1     5938
#  0    15764
#  1        4
#  2     3819
#  3      240
#  4       76
#  5       21
#  6       23
#  7       27
#  8        3
# Name: count, dtype: int64
#
# PAY_4
# PAY_4
# -2     4348
# -1     5687
#  0    16455
#  1        2
#  2     3159
#  3      180
#  4       69
#  5       35
#  6        5
#  7       58
#  8        2
# Name: count, dtype: int64
#
# PAY_5
# PAY_5
# -2     4546
# -1     5539
#  0    16947
#  2     2626
#  3      178
#  4       84
#  5       17
#  6        4
#  7       58
#  8        1
# Name: count, dtype: int64
#
# PAY_6
# ...

# %%
df[pay_columns].describe()
# Out:
#               PAY_0         PAY_2         PAY_3         PAY_4         PAY_5  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      -0.016700     -0.133767     -0.166200     -0.220667     -0.266200
# std        1.123802      1.197186      1.196868      1.169139      1.133187
# min       -2.000000     -2.000000     -2.000000     -2.000000     -2.000000
# 25%       -1.000000     -1.000000     -1.000000     -1.000000     -1.000000
# 50%        0.000000      0.000000      0.000000      0.000000      0.000000
# 75%        0.000000      0.000000      0.000000      0.000000      0.000000
# max        8.000000      8.000000      8.000000      8.000000      8.000000
#
#               PAY_6
# count  30000.000000
# mean      -0.291100
# std        1.149988
# min       -2.000000
# 25%       -1.000000
# 50%        0.000000
# 75%        0.000000
# max        8.000000

# %%
repayment_counts = pd.DataFrame({
    column: df[column].value_counts().sort_index()
    for column in pay_columns
})

repayment_counts
# Out:
#     PAY_0  PAY_2  PAY_3  PAY_4    PAY_5    PAY_6
# -2   2759   3782   4085   4348   4546.0   4895.0
# -1   5686   6050   5938   5687   5539.0   5740.0
#  0  14737  15730  15764  16455  16947.0  16286.0
#  1   3688     28      4      2      NaN      NaN
#  2   2667   3927   3819   3159   2626.0   2766.0
#  3    322    326    240    180    178.0    184.0
#  4     76     99     76     69     84.0     49.0
#  5     26     25     21     35     17.0     13.0
#  6     11     12     23      5      4.0     19.0
#  7      9     20     27     58     58.0     46.0
#  8     19      1      3      2      1.0      2.0

# %%
bill_columns = [
    "BILL_AMT1", "BILL_AMT2", "BILL_AMT3",
    "BILL_AMT4", "BILL_AMT5", "BILL_AMT6"
]

payment_columns = [
    "PAY_AMT1", "PAY_AMT2", "PAY_AMT3",
    "PAY_AMT4", "PAY_AMT5", "PAY_AMT6"
]

numerical_columns = [
    "LIMIT_BAL",
    "AGE",
    *bill_columns,
    *payment_columns
]

# %%
df[numerical_columns].describe().T
# Out:
#              count           mean            std       min       25%  \
# LIMIT_BAL  30000.0  167484.322667  129747.661567   10000.0  50000.00
# AGE        30000.0      35.485500       9.217904      21.0     28.00
# BILL_AMT1  30000.0   51223.330900   73635.860576 -165580.0   3558.75
# BILL_AMT2  30000.0   49179.075167   71173.768783  -69777.0   2984.75
# BILL_AMT3  30000.0   47013.154800   69349.387427 -157264.0   2666.25
# BILL_AMT4  30000.0   43262.948967   64332.856134 -170000.0   2326.75
# BILL_AMT5  30000.0   40311.400967   60797.155770  -81334.0   1763.00
# BILL_AMT6  30000.0   38871.760400   59554.107537 -339603.0   1256.00
# PAY_AMT1   30000.0    5663.580500   16563.280354       0.0   1000.00
# PAY_AMT2   30000.0    5921.163500   23040.870402       0.0    833.00
# PAY_AMT3   30000.0    5225.681500   17606.961470       0.0    390.00
# PAY_AMT4   30000.0    4826.076867   15666.159744       0.0    296.00
# PAY_AMT5   30000.0    4799.387633   15278.305679       0.0    252.50
# ...

# %%
df["AGE"].describe()
# Out:
# count    30000.000000
# mean        35.485500
# std          9.217904
# min         21.000000
# 25%         28.000000
# 50%         34.000000
# 75%         41.000000
# max         79.000000
# Name: AGE, dtype: float64

# %%
df["AGE"].value_counts().sort_index()
# Out:
# AGE
# 21      67
# 22     560
# 23     931
# 24    1127
# 25    1186
# 26    1256
# 27    1477
# 28    1409
# 29    1605
# 30    1395
# 31    1217
# 32    1158
# 33    1146
# 34    1162
# 35    1113
# 36    1108
# 37    1041
# 38     944
# 39     954
# 40     870
# 41     824
# 42     794
# 43     670
# 44     700
# 45     617
# 46     570
# 47     501
# 48     466
# 49     452
# 50     411
# 51     340
# 52     304
# 53     325
# 54     247
# 55     209
# 56     178
# 57     122
# 58     122
# 59      83
# 60      67
# 61      56
# 62      44
# 63      31
# 64      31
# 65      24
# 66      25
# 67      16
# 68       5
# 69      15
# 70      10
# 71       3
# 72       3
# 73       4
# 74       1
# 75       3
# 79       1
# Name: count, dtype: int64

# %%
df["LIMIT_BAL"].describe()
# Out:
# count      30000.000000
# mean      167484.322667
# std       129747.661567
# min        10000.000000
# 25%        50000.000000
# 50%       140000.000000
# 75%       240000.000000
# max      1000000.000000
# Name: LIMIT_BAL, dtype: float64

# %%
df["AGE"].value_counts().sort_index()
# Out:
# AGE
# 21      67
# 22     560
# 23     931
# 24    1127
# 25    1186
# 26    1256
# 27    1477
# 28    1409
# 29    1605
# 30    1395
# 31    1217
# 32    1158
# 33    1146
# 34    1162
# 35    1113
# 36    1108
# 37    1041
# 38     944
# 39     954
# 40     870
# 41     824
# 42     794
# 43     670
# 44     700
# 45     617
# 46     570
# 47     501
# 48     466
# 49     452
# 50     411
# 51     340
# 52     304
# 53     325
# 54     247
# 55     209
# 56     178
# 57     122
# 58     122
# 59      83
# 60      67
# 61      56
# 62      44
# 63      31
# 64      31
# 65      24
# 66      25
# 67      16
# 68       5
# 69      15
# 70      10
# 71       3
# 72       3
# 73       4
# 74       1
# 75       3
# 79       1
# Name: count, dtype: int64

# %%
df[numerical_columns].describe().T
# Out:
#              count           mean            std       min       25%  \
# LIMIT_BAL  30000.0  167484.322667  129747.661567   10000.0  50000.00
# AGE        30000.0      35.485500       9.217904      21.0     28.00
# BILL_AMT1  30000.0   51223.330900   73635.860576 -165580.0   3558.75
# BILL_AMT2  30000.0   49179.075167   71173.768783  -69777.0   2984.75
# BILL_AMT3  30000.0   47013.154800   69349.387427 -157264.0   2666.25
# BILL_AMT4  30000.0   43262.948967   64332.856134 -170000.0   2326.75
# BILL_AMT5  30000.0   40311.400967   60797.155770  -81334.0   1763.00
# BILL_AMT6  30000.0   38871.760400   59554.107537 -339603.0   1256.00
# PAY_AMT1   30000.0    5663.580500   16563.280354       0.0   1000.00
# PAY_AMT2   30000.0    5921.163500   23040.870402       0.0    833.00
# PAY_AMT3   30000.0    5225.681500   17606.961470       0.0    390.00
# PAY_AMT4   30000.0    4826.076867   15666.159744       0.0    296.00
# PAY_AMT5   30000.0    4799.387633   15278.305679       0.0    252.50
# ...

# %%
from pathlib import Path

# Create the processed data folder if it doesn't already exist
processed_dir = Path("../data/processed")
processed_dir.mkdir(parents=True, exist_ok=True)

# Save the cleaned dataset
df.to_csv(processed_dir / "credit_default_clean.csv", index=False)

print("Saved successfully!")
# Out:
# Saved successfully!

# %%
from pathlib import Path
import pandas as pd

print("Current folder:", Path.cwd())

# Create the output folder
output_file = Path.cwd().parent / "data" / "processed" / "credit_default_clean.csv"
output_file.parent.mkdir(parents=True, exist_ok=True)

# Save your dataframe
df.to_csv(output_file, index=False)

print("Saved to:", output_file)
print("Exists:", output_file.exists())
# Out:
# Current folder: /Users/najmanuur/Desktop/credit-risk-prediction
# Saved to: /Users/najmanuur/Desktop/data/processed/credit_default_clean.csv
# Exists: True

# %%
from pathlib import Path

project_root = Path.cwd()

output_file = project_root / "data" / "processed" / "credit_default_clean.csv"
output_file.parent.mkdir(parents=True, exist_ok=True)

df.to_csv(output_file, index=False)

print("Saved to:", output_file)
print("Exists:", output_file.exists())
# Out:
# Saved to: /Users/najmanuur/Desktop/credit-risk-prediction/data/processed/credit_default_clean.csv
# Exists: True
